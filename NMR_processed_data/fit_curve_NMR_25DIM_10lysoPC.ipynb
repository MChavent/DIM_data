# %%
#importing numpy
import numpy as np

# importing matplotlib to perform figures
import matplotlib.pyplot as plt

from scipy.optimize import curve_fit

# %%
list_temp=[]
list_PC=[]
list_PE=[]
counter=0
file = open('RMN_31P_fit_25perc_DIM_10perc_LYSO.csv', "r")

for line in file.readlines():

    if counter > 0:
        line_values = line.split()
        values = [float(x) for x in line_values]
        list_temp.append(int(values[0]))
        list_PC.append(values[1])     
        list_PE.append(values[2])   
    counter=counter+1

# %%
xdata = np.linspace(284, 326, 100)

def sigmoid(x, xo,k, A):
    y = A-A/(1+ np.exp(-k*(x-xo)))
    return y

p_start1=[284,0.3,120]
p_start2=[284,0.3,80]

list_err=[5] * len(list_temp)

popt1, pcov1 = curve_fit(sigmoid, list_temp, list_PC, p0=p_start1, sigma=list_err)
popt2, pcov2 = curve_fit(sigmoid, list_temp, list_PE, p0=p_start2, sigma=list_err)


print popt1
print popt2

fig = plt.figure(figsize=(8.5, 7))
ax = fig.add_subplot(111)

# values from Table S3
ax.plot(xdata, sigmoid(xdata, *[329.3,0.11,102.3]), "--", color='#3299ff')
ax.plot(list_temp, list_PC,'s', markersize=8, mew='1.5', color='#3299ff', alpha=0.5)
ax.plot(list_temp, list_PC,'s', markersize=8, mfc='none', mew='1.5', color='#3299ff', alpha=0.5)

# values from Table S3
ax.plot(xdata, sigmoid(xdata, *[321.2,0.12,83.7]), "-", color='#3299ff')
ax.plot(list_temp, list_PE,'o', markersize=8, mew='1.5', color='#3299ff', alpha=0.5)
ax.plot(list_temp, list_PE,'o', markersize=8, mfc='none', mew='1.5', color='#3299ff')

plt.ylim(-10,110)

fig.savefig("DIM25_lyso10_fit_skyblue.svg", dpi=200)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.
# [3.29291968e+02 1.06102757e-01 1.02348258e+02]
# [3.21326027e+02 1.18730195e-01 8.35447193e+01]
